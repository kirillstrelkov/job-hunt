# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import re
import sys
from pathlib import Path

import pandas as pd
from IPython.display import display

# Add tools/py to path to import helpers
sys.path.append(str(Path.cwd().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path.cwd()))
from run import RESULTS_CSV

pd.set_option("max_colwidth", 120)

df = pd.read_csv(RESULTS_CSV)

for col in [PromptfooCsvCols.PROVIDER_ID, PromptfooCsvCols.PROVIDER_LABEL]:
    display(df[col].drop_duplicates().sort_values().head().reset_index(drop=True))
# Out:
# 2026-07-06 17:02:13.059 | INFO     | config.config:load:391 - Loading configuration from /home/kirill/prj/gh/job-hunt/tools/py/config/config.yaml
# 0    google:gemini-3.1-flash-lite
# 1         google:gemini-3.5-flash
# 2       google:gemma-4-26b-a4b-it
# 3           google:gemma-4-31b-it
# 4    ollama:chat:deepseek-r1:1.5b
# Name: Provider Id, dtype: str
# 0                deepseek-r1:1.5b (ctx=32768,pred=-1, temp=0.1)
# 1                  deepseek-r1:7b (ctx=32768,pred=-1, temp=0.1)
# 2    gemini-3.1-flash-lite (ctx=1048576,pred=default, temp=0.1)
# 3         gemini-3.5-flash (ctx=1048576,pred=default, temp=0.1)
# 4        gemma-4-26b-a4b-it (ctx=256000,pred=default, temp=0.1)
# Name: Provider Label, dtype: str

# %%
df = df.sort_values(
    by=[PromptfooCsvCols.SCORE, PromptfooCsvCols.COMPLETION_TOKENS, PromptfooCsvCols.LATENCY],
    ascending=[False, False, True],
)

# fix long prompt label - leave only file name
df[PromptfooCsvCols.PROMPT_LABEL] = df[PromptfooCsvCols.PROMPT_LABEL].apply(lambda x: re.findall(r"\w+\.md", x)[0])

df[
    [
        PromptfooCsvCols.PROVIDER_LABEL,
        PromptfooCsvCols.PROMPT_LABEL,
        PromptfooCsvCols.SUCCESS,
        PromptfooCsvCols.SCORE,
        PromptfooCsvCols.PASSED,
        PromptfooCsvCols.FAILED,
        PromptfooCsvCols.LATENCY,
        PromptfooCsvCols.COMPLETION_TOKENS,
        PromptfooCsvCols.FAILURE_REASON,
    ]
].head(20).reset_index(drop=True)
# Out:
#                                                   Provider Label  \
# 0         gemma-4-26b-a4b-it (ctx=256000,pred=default, temp=0.1)
# 1             gemma-4-31b-it (ctx=256000,pred=default, temp=0.1)
# 2                gemma4:e2b-it-qat (ctx=32768,pred=-1, temp=0.1)
# 3                gemma4:e4b-it-qat (ctx=32768,pred=-1, temp=0.1)
# 4                gemma4:e2b-ctx16k (ctx=32768,pred=-1, temp=0.1)
# 5                gemma4:e2b-ctx32k (ctx=32768,pred=-1, temp=0.1)
# 6     gemini-3.1-flash-lite (ctx=1048576,pred=default, temp=0.1)
# 7                       gemma4:e2b (ctx=32768,pred=-1, temp=0.1)
# 8                 qwen2.5-coder:7b (ctx=32768,pred=-1, temp=0.1)
# 9          nemotron-3-nano:4b-q8_0 (ctx=32768,pred=-1, temp=0.1)
# 10                qwen2.5-coder:3b (ctx=32768,pred=-1, temp=0.1)
# 11                      qwen2.5:7b (ctx=32768,pred=-1, temp=0.1)
# 12        qwen2.5:3b-instruct-q8_0 (ctx=32768,pred=-1, temp=0.1)
# 13               qwen3.5:4b-q4_K_M (ctx=32768,pred=-1, temp=0.1)
# 14                deepseek-r1:1.5b (ctx=32768,pred=-1, temp=0.1)
# 15                  deepseek-r1:7b (ctx=32768,pred=-1, temp=0.1)
# 16  nemotron-mini:4b-instruct-q8_0 (ctx=32768,pred=-1, temp=0.1)
# 17         gemini-3.5-flash (ctx=1048576,pred=default, temp=0.1)
#
#      Prompt Label Success     Score  Passed  Failed  Latency (s)  \
# 0   llm_prompt.md    PASS  0.980152      23       0      176.250
# 1   llm_prompt.md    PASS  0.978045      23       0      188.828
# 2   llm_prompt.md    FAIL  0.890888      21       2       41.732
# 3   llm_prompt.md    FAIL  0.845263      20       3       70.638
# 4   llm_prompt.md    FAIL  0.806141      19       4       21.276
# 5   llm_prompt.md    FAIL  0.806141      19       4       24.484
# 6   llm_prompt.md    FAIL  0.801980      19       4        5.860
# 7   llm_prompt.md    FAIL  0.761414      18       5       25.704
# 8   llm_prompt.md    FAIL  0.667854      16       7       36.979
# 9   llm_prompt.md    FAIL  0.663532      16       7       71.094
# 10  llm_prompt.md    FAIL  0.627918      15       8       71.380
# 11  llm_prompt.md    FAIL  0.442148      11      12       31.574
# 12  llm_prompt.md    FAIL  0.402386      10      13       30.505
# 13  llm_prompt.md    FAIL  0.305365       7      16      108.180
# 14  llm_prompt.md    FAIL  0.185088       5      18       23.654
# 15  llm_prompt.md    FAIL  0.171829       3      20       35.982
# 16  llm_prompt.md    FAIL  0.110786       2      21       17.859
# 17  llm_prompt.md    FAIL  0.000000       0       0        2.017
#
#     Completion Tokens  \
# 0                2284
# 1                2085
# 2                3573
# 3                3414
# 4                2817
# 5                2817
# 6                1380
# 7                2839
# 8                1389
# 9                3967
# 10               4131
# 11                875
# 12               1555
# 13               7349
# 14               1895
# 15               1226
# 16                 90
# 17                  0
#
#                                                                                                              Failure Reason
# 0                                                                                                                       NaN
# 1                                                                                                                       NaN
# 2                   Expected output to contain "**Software Engineer** | _CARIAD SE, Berlin, Germany_ | Oct 2023 - Aug 2025"
# 3   Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 4   Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 5   Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 6                                                                            Expected output to contain "Ixonos Estonia OÜ"
# 7   Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 8   Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 9                                                                  Python code returned false len(output.splitlines()) > 70
# 10  API response error: Error: No embedding found in Ollama embeddings API response: {"error":"the input length exceeds ...
# 11  The submitted answer and the expert answer differ in the specific content of the tailored resume (Part 1) and the de...
# 12  The submitted answer differs from the expert answer in the structure of the final output (Part 1, Part 2, and Part 3...
# 13                                                                            ROUGE-N score 0.26 is less than threshold 0.3
# 14  The submitted answer does not align with the structure, formatting, or strict constraints imposed by the prompt, whi...
# 15  There is a disagreement between the submitted answer and the expert answer because the submitted answer fails to adh...
# 16                                                                            ROUGE-N score 0.06 is less than threshold 0.3
# 17                                                                                                                        2
