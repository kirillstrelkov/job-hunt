# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import os
import sys
import re
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# Add tools/py to path to import helpers
sys.path.append(str(Path(".").resolve().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path(".").resolve()))
from run import RESULTS_CSV

pd.set_option('max_colwidth', 120)

df = pd.read_csv(RESULTS_CSV)
df = df.sort_values(by=PromptfooCsvCols.SCORE, ascending=False)
print("Number of models:", len(df[PromptfooCsvCols.PROVIDER_ID].unique()))
display(df[PromptfooCsvCols.PROVIDER_ID].drop_duplicates().sort_values().reset_index(drop=True))
print("Shape:", df.shape)
# Out:
# Number of models: 3
# 0           ollama:chat:gemma4:e2b
# 1    ollama:chat:gemma4:e4b-it-qat
# 2      ollama:chat:qwen3.5:4b-q8_0
# Name: Provider Id, dtype: str
# Shape: (6, 12)

# %%
# fix long prompt label - leave only file name
df[PromptfooCsvCols.PROMPT_LABEL] = df[PromptfooCsvCols.PROMPT_LABEL].apply(lambda x: re.findall(r'\w+\.md', x)[0])

df[[
    PromptfooCsvCols.PROVIDER_LABEL,
    PromptfooCsvCols.PROMPT_LABEL,
    PromptfooCsvCols.SUCCESS,
    PromptfooCsvCols.SCORE,
    PromptfooCsvCols.PASSED,
    PromptfooCsvCols.FAILED,
    PromptfooCsvCols.LATENCY,
    PromptfooCsvCols.COMPLETION_TOKENS,
    PromptfooCsvCols.FAILURE_REASON,
]].head(20).reset_index(drop=True)
# Out:
#                                      Provider Label   Prompt Label Success  \
# 0         gemma4:e2b (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 1         gemma4:e2b (ctx=16384, pred=-1, temp=0.0)  llm_prompt.md    FAIL
# 2    qwen3.5:4b-q8_0 (ctx=16384, pred=-1, temp=0.0)  llm_prompt.md    FAIL
# 3    qwen3.5:4b-q8_0 (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 4  gemma4:e4b-it-qat (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 5  gemma4:e4b-it-qat (ctx=16384, pred=-1, temp=0.0)  llm_prompt.md    FAIL
#
#       Score  Passed  Failed  Latency (s)  Completion Tokens  \
# 0  0.687211       8       4       31.646               3318
# 1  0.603254       7       5       22.454               2989
# 2  0.520738       6       6      136.380               7085
# 3  0.520519       6       6      121.831               6010
# 4  0.519998       6       6       61.709               3807
# 5  0.435739       5       7       57.019               3569
#
#                                   Failure Reason
# 0  ROUGE-N score 0.25 is less than threshold 0.3
# 1  ROUGE-N score 0.24 is less than threshold 0.3
# 2  ROUGE-N score 0.25 is less than threshold 0.3
# 3  ROUGE-N score 0.25 is less than threshold 0.3
# 4  ROUGE-N score 0.24 is less than threshold 0.3
# 5  ROUGE-N score 0.23 is less than threshold 0.3
