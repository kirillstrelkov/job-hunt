# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import os
import sys
import re
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# Add tools/py to path to import helpers
sys.path.append(str(Path(".").resolve().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path(".").resolve()))
from run import RESULTS_CSV

pd.set_option('max_colwidth', 120)

df = pd.read_csv(RESULTS_CSV)

for col in [PromptfooCsvCols.PROVIDER_ID, PromptfooCsvCols.PROVIDER_LABEL]:
    print(f"Column '{col}': unique values:", len(df[col].unique()), "NOTE: listing only head:")
    display(df[col].drop_duplicates().sort_values().head().reset_index(drop=True))

print("Shape:", df.shape)
# Out:
# Column 'Provider Id': unique values: 3 NOTE: listing only head:
# 0           ollama:chat:gemma4:e2b
# 1    ollama:chat:gemma4:e4b-it-qat
# 2      ollama:chat:qwen3.5:4b-q8_0
# Name: Provider Id, dtype: str
# Column 'Provider Label': unique values: 6 NOTE: listing only head:
# 0           gemma4:e2b (ctx=16384, pred=-1, temp=0.1)
# 1           gemma4:e2b (ctx=32768, pred=-1, temp=0.1)
# 2    gemma4:e4b-it-qat (ctx=16384, pred=-1, temp=0.1)
# 3    gemma4:e4b-it-qat (ctx=32768, pred=-1, temp=0.1)
# 4      qwen3.5:4b-q8_0 (ctx=16384, pred=-1, temp=0.1)
# Name: Provider Label, dtype: str
# Shape: (6, 12)

# %%
df = df.sort_values(
    by=[PromptfooCsvCols.SCORE, PromptfooCsvCols.COMPLETION_TOKENS, PromptfooCsvCols.LATENCY], 
    ascending=[False, False, True]
)

# fix long prompt label - leave only file name
df[PromptfooCsvCols.PROMPT_LABEL] = df[PromptfooCsvCols.PROMPT_LABEL].apply(lambda x: re.findall(r'\w+\.md', x)[0])

df[[
    PromptfooCsvCols.PROVIDER_LABEL,
    PromptfooCsvCols.PROMPT_LABEL,
    PromptfooCsvCols.SUCCESS,
    PromptfooCsvCols.SCORE,
    PromptfooCsvCols.PASSED,
    PromptfooCsvCols.FAILED,
    PromptfooCsvCols.LATENCY,
    PromptfooCsvCols.COMPLETION_TOKENS,
    PromptfooCsvCols.FAILURE_REASON,
]].head(20).reset_index(drop=True)
# Out:
#                                      Provider Label   Prompt Label Success  \
# 0         gemma4:e2b (ctx=32768, pred=-1, temp=0.1)  llm_prompt.md    PASS
# 1         gemma4:e2b (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    PASS
# 2  gemma4:e4b-it-qat (ctx=32768, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 3  gemma4:e4b-it-qat (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 4    qwen3.5:4b-q8_0 (ctx=16384, pred=-1, temp=0.1)  llm_prompt.md    FAIL
# 5    qwen3.5:4b-q8_0 (ctx=32768, pred=-1, temp=0.1)  llm_prompt.md    FAIL
#
#       Score  Passed  Failed  Latency (s)  Completion Tokens  \
# 0  0.960382      13       0       30.623               3318
# 1  0.960382      13       0       31.589               3318
# 2  0.734842      10       3       59.995               3807
# 3  0.734842      10       3       74.352               3807
# 4  0.730787      10       3      121.447               6010
# 5  0.729787      10       3      195.445               9025
#
#                                                                                                             Failure Reason
# 0                                                                                                                      NaN
# 1                                                                                                                      NaN
# 2  Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 3  Expected output to contain "**[University of Helsinki DevOps Labs: Cloud-Native Microservices](https://github.com/ki...
# 4  Expected output to contain "Certified Kubernetes Application Developer, _Cloud Native Computing Foundation_ | Feb 2026"
# 5  Expected output to contain "Certified Kubernetes Application Developer, _Cloud Native Computing Foundation_ | Feb 2026"
