# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import os
import sys
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# Add tools/py to path to import helpers
sys.path.append(str(Path(".").resolve().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path(".").resolve()))
from run import RESULTS_CSV

df = pd.read_csv(RESULTS_CSV)
df = df.sort_values(by=PromptfooCsvCols.SCORE, ascending=False)

df[[
    PromptfooCsvCols.PROVIDER_ID,
    PromptfooCsvCols.PROVIDER_LABEL,
    PromptfooCsvCols.PROMPT_LABEL,
    PromptfooCsvCols.SUCCESS,
    PromptfooCsvCols.SCORE,
    PromptfooCsvCols.PASSED,
    PromptfooCsvCols.FAILED,
]]
# Out:
#                      Provider Id  \
# 0  ollama:chat:gemma4:e2b-it-qat
# 2  ollama:chat:gemma4:e2b-it-qat
# 4  ollama:chat:gemma4:e2b-it-qat
# 5  ollama:chat:gemma4:e2b-it-qat
# 1  ollama:chat:gemma4:e2b-it-qat
# 3  ollama:chat:gemma4:e2b-it-qat
#
#                                       Provider Label  \
# 0   gemma4:e2b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 2  gemma4:e2b-it-qat (ctx=12288, pred=8192, temp=...
# 4  gemma4:e2b-it-qat (ctx=12288, pred=7168, temp=...
# 5  gemma4:e2b-it-qat (ctx=12288, pred=7168, temp=...
# 1   gemma4:e2b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 3  gemma4:e2b-it-qat (ctx=12288, pred=8192, temp=...
#
#                                         Prompt Label Success     Score  \
# 0  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.438762
# 2  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.438762
# 4  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.436810
# 5  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.354683
# 1  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.354236
# 3  /home/kirill/prj/gh/job-hunt/tools/py/tailor_c...    FAIL  0.354236
#
#    Passed  Failed
# 0       5       7
# 2       5       7
# 4       5       7
# 5       4       8
# 1       4       8
# 3       4       8
