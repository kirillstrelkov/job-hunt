# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import os
import sys
import re
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# Add tools/py to path to import helpers
sys.path.append(str(Path(".").resolve().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path(".").resolve()))
from run import RESULTS_CSV

pd.set_option('max_colwidth', 120)

df = pd.read_csv(RESULTS_CSV)
df = df.sort_values(by=PromptfooCsvCols.SCORE, ascending=False)
print("Number of models:", len(df[PromptfooCsvCols.PROVIDER_ID].unique()))
display(df[PromptfooCsvCols.PROVIDER_ID].drop_duplicates().sort_values().reset_index(drop=True))
print("Shape:", df.shape)
# Out:
# Number of models: 6
# 0          ollama:chat:gemma4:12b-it-qat
# 1                 ollama:chat:gemma4:e2b
# 2          ollama:chat:gemma4:e4b-it-qat
# 3    ollama:chat:llama3.1:8b-text-q4_K_M
# 4            ollama:chat:qwen3.5:4b-q8_0
# 5          ollama:chat:qwen3.5:9b-q4_K_M
# Name: Provider Id, dtype: str
# Shape: (108, 12)

# %%
# fix long prompt label - leave only file name
df[PromptfooCsvCols.PROMPT_LABEL] = df[PromptfooCsvCols.PROMPT_LABEL].apply(lambda x: re.findall(r'\w+\.md', x)[0])

df[[
    PromptfooCsvCols.PROVIDER_LABEL,
    PromptfooCsvCols.PROMPT_LABEL,
    PromptfooCsvCols.SUCCESS,
    PromptfooCsvCols.SCORE,
    PromptfooCsvCols.PASSED,
    PromptfooCsvCols.FAILED,
    PromptfooCsvCols.LATENCY,
    PromptfooCsvCols.COMPLETION_TOKENS,
    PromptfooCsvCols.FAILURE_REASON,
]].head(20).reset_index(drop=True)
# Out:
#                                             Provider Label  \
# 0       gemma4:12b-it-qat (ctx=12288, pred=7168, temp=0.0)
# 1         gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.0)
# 2       gemma4:12b-it-qat (ctx=12288, pred=8192, temp=0.0)
# 3              gemma4:e2b (ctx=12288, pred=7168, temp=0.1)
# 4                gemma4:e2b (ctx=16384, pred=-1, temp=0.1)
# 5              gemma4:e2b (ctx=12288, pred=8192, temp=0.1)
# 6                gemma4:e2b (ctx=16384, pred=-1, temp=0.2)
# 7              gemma4:e2b (ctx=12288, pred=8192, temp=0.2)
# 8           qwen3.5:4b-q8_0 (ctx=16384, pred=-1, temp=0.1)
# 9   llama3.1:8b-text-q4_K_M (ctx=16384, pred=-1, temp=0.2)
# 10  llama3.1:8b-text-q4_K_M (ctx=16384, pred=-1, temp=0.1)
# 11  llama3.1:8b-text-q4_K_M (ctx=16384, pred=-1, temp=0.0)
# 12      gemma4:12b-it-qat (ctx=12288, pred=8192, temp=0.0)
# 13        gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.0)
# 14      gemma4:12b-it-qat (ctx=12288, pred=7168, temp=0.0)
# 15        gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 16      gemma4:12b-it-qat (ctx=12288, pred=8192, temp=0.2)
# 17      gemma4:12b-it-qat (ctx=12288, pred=7168, temp=0.2)
# 18        gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 19      gemma4:12b-it-qat (ctx=12288, pred=7168, temp=0.2)
#
#                        Prompt Label Success     Score  Passed  Failed  \
# 0   tone_style_part3_add_options.md    FAIL  0.605569       7       5
# 1   tone_style_part3_add_options.md    FAIL  0.605569       7       5
# 2   tone_style_part3_add_options.md    FAIL  0.605569       7       5
# 3   tone_style_part3_add_options.md    FAIL  0.605051       7       5
# 4   tone_style_part3_add_options.md    FAIL  0.605051       7       5
# 5   tone_style_part3_add_options.md    FAIL  0.605051       7       5
# 6   tone_style_part3_add_options.md    FAIL  0.604500       7       5
# 7   tone_style_part3_add_options.md    FAIL  0.604500       7       5
# 8   tone_style_part3_add_options.md    FAIL  0.603533       7       5
# 9   tone_style_part3_add_options.md    FAIL  0.594926       7       5
# 10  tone_style_part3_add_options.md    FAIL  0.594926       7       5
# 11  tone_style_part3_add_options.md    FAIL  0.594926       7       5
# 12                      previous.md    FAIL  0.523073       6       6
# 13                      previous.md    FAIL  0.523073       6       6
# 14                      previous.md    FAIL  0.523073       6       6
# 15                      previous.md    FAIL  0.522659       6       6
# 16                      previous.md    FAIL  0.522659       6       6
# 17                      previous.md    FAIL  0.522659       6       6
# 18  tone_style_part3_add_options.md    FAIL  0.522550       6       6
# 19  tone_style_part3_add_options.md    FAIL  0.522550       6       6
#
#     Latency (s)  Completion Tokens  \
# 0       259.195               3469
# 1       256.902               3469
# 2       260.063               3469
# 3        20.703               2696
# 4        20.630               2696
# 5        20.760               2696
# 6        42.378               2519
# 7        27.255               2519
# 8       135.273               7105
# 9       245.878               7818
# 10      242.505               7818
# 11      240.181               7818
# 12      274.117               3649
# 13      269.740               3649
# 14      272.901               3649
# 15      284.186               3963
# 16      293.224               3963
# 17      287.858               3963
# 18      273.342               3644
# 19      269.005               3644
#
#                                    Failure Reason
# 0   ROUGE-N score 0.27 is less than threshold 0.3
# 1   ROUGE-N score 0.27 is less than threshold 0.3
# 2   ROUGE-N score 0.27 is less than threshold 0.3
# 3   ROUGE-N score 0.26 is less than threshold 0.3
# 4   ROUGE-N score 0.26 is less than threshold 0.3
# 5   ROUGE-N score 0.26 is less than threshold 0.3
# 6   ROUGE-N score 0.25 is less than threshold 0.3
# 7   ROUGE-N score 0.25 is less than threshold 0.3
# 8   ROUGE-N score 0.24 is less than threshold 0.3
# 9   ROUGE-N score 0.14 is less than threshold 0.3
# 10  ROUGE-N score 0.14 is less than threshold 0.3
# 11  ROUGE-N score 0.14 is less than threshold 0.3
# 12  ROUGE-N score 0.28 is less than threshold 0.3
# 13  ROUGE-N score 0.28 is less than threshold 0.3
# 14  ROUGE-N score 0.28 is less than threshold 0.3
# 15  ROUGE-N score 0.27 is less than threshold 0.3
# 16  ROUGE-N score 0.27 is less than threshold 0.3
# 17  ROUGE-N score 0.27 is less than threshold 0.3
# 18  ROUGE-N score 0.27 is less than threshold 0.3
# 19  ROUGE-N score 0.27 is less than threshold 0.3
