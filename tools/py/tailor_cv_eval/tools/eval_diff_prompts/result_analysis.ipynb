# %% [markdown]
# # Evaluation Results Analysis
# Analyze and display Promptfoo CV tailoring prompt evaluation results.

# %%
import os
import sys
import re
from pathlib import Path
import pandas as pd
from IPython.display import display, Markdown

# Add tools/py to path to import helpers
sys.path.append(str(Path(".").resolve().parents[2]))
from helpers.promptfoo_helper import PromptfooCsvCols

# Import globals from run.py
sys.path.append(str(Path(".").resolve()))
from run import RESULTS_CSV

pd.set_option('max_colwidth', 120)

df = pd.read_csv(RESULTS_CSV)
df = df.sort_values(by=PromptfooCsvCols.SCORE, ascending=False)

# fix long prompt label
df[PromptfooCsvCols.PROMPT_LABEL] = df[PromptfooCsvCols.PROMPT_LABEL].apply(lambda x: re.findall(r'\w+\.md', x)[0])

df[[
    PromptfooCsvCols.PROVIDER_LABEL,
    PromptfooCsvCols.PROMPT_LABEL,
    PromptfooCsvCols.SUCCESS,
    PromptfooCsvCols.SCORE,
    PromptfooCsvCols.PASSED,
    PromptfooCsvCols.FAILED,
]].head(10)
# Out:
#                                             Provider Label  \
# 70             gemma4:e2b (ctx=12288, pred=7168, temp=0.1)
# 66               gemma4:e2b (ctx=16384, pred=-1, temp=0.2)
# 68             gemma4:e2b (ctx=12288, pred=8192, temp=0.2)
# 0   llama3.1:8b-text-q4_K_M (ctx=16384, pred=-1, temp=0.2)
# 43        gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 45      gemma4:12b-it-qat (ctx=12288, pred=8192, temp=0.2)
# 44      gemma4:12b-it-qat (ctx=12288, pred=8192, temp=0.2)
# 42        gemma4:12b-it-qat (ctx=16384, pred=-1, temp=0.2)
# 10      gemma4:e4b-it-qat (ctx=12288, pred=7168, temp=0.1)
# 67               gemma4:e2b (ctx=16384, pred=-1, temp=0.2)
#
#                        Prompt Label Success     Score  Passed  Failed
# 70  tone_style_part3_add_options.md    FAIL  0.688385       8       4
# 66  tone_style_part3_add_options.md    FAIL  0.687834       8       4
# 68  tone_style_part3_add_options.md    FAIL  0.687834       8       4
# 0   tone_style_part3_add_options.md    FAIL  0.678260       8       4
# 43                      previous.md    FAIL  0.605993       7       5
# 45                      previous.md    FAIL  0.605993       7       5
# 44  tone_style_part3_add_options.md    FAIL  0.605884       7       5
# 42  tone_style_part3_add_options.md    FAIL  0.605884       7       5
# 10  tone_style_part3_add_options.md    FAIL  0.605454       7       5
# 67                      previous.md    FAIL  0.604987       7       5
